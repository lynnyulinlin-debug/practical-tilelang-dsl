# %% [markdown]
# # Chapter 8 Platform Layer
#
# This notebook explains the platform-specific migration layer.
#
# Use this layer to compare CUDA, ROCm, and Ascend-style concerns after the unified workflow is clear.

# %% [markdown]
# ## What this layer teaches
#
# - What to verify first on each backend
# - Which parameters should not be copied blindly
# - How to read a platform difference as a validation order
# - Why a single benchmark field format matters

# %% [markdown]
# ## Matching notebook
#
# `examples/08_gemm_porting.ipynb`
