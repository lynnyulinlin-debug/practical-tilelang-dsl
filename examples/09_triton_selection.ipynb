# %% [markdown]
# # Chapter 9 Selection Layer
#
# This notebook explains the route-selection layer.
#
# Use this layer to decide when Triton is the better fit and when TileLang is the better fit.

# %% [markdown]
# ## What this layer teaches
#
# - How to compare control surface vs abstraction level
# - How to think about team experience and migration cost
# - How to decide based on constraints instead of style preference
# - How to keep the selection criteria explicit in the write-up

# %% [markdown]
# ## Matching notebook
#
# `examples/09_triton_comparison.ipynb`
