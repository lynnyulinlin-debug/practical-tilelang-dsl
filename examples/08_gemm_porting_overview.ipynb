# %% [markdown]
# # Chapter 8 Overview Layer
#
# This notebook explains the cross-backend migration workflow.
#
# Use this layer to understand the shared methodology before looking at platform-specific differences.

# %% [markdown]
# ## What this layer teaches
#
# - How to define a unified benchmark record
# - How to keep logic and target-specific config separate
# - How to choose what can be reused across backends
# - How to think about migration as a repeatable workflow

# %% [markdown]
# ## Matching notebook
#
# `examples/08_gemm_porting.ipynb`
