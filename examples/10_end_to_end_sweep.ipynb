# %% [markdown]
# # Chapter 10 Sweep Layer
#
# This notebook explains the trend-scan layer.
#
# Use this layer to understand why single-point benchmark results are not enough.

# %% [markdown]
# ## What this layer teaches
#
# - Why sequence-length sweeps matter
# - Why a blockwise path may reverse at a different scale
# - Why the report should keep `sweep_enabled`
# - Why a good project record needs a trend, not only a point estimate

# %% [markdown]
# ## Matching script
#
# `examples/10_end_to_end_sweep.py`
