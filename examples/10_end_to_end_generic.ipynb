# %% [markdown]
# # Chapter 10 Generic Project Layer
#
# This notebook explains the chapter-level project layer.
#
# Use this layer when you want to understand the full migration workflow without binding the case to a specific public brand.

# %% [markdown]
# ## What this layer teaches
#
# - How to choose a subgraph
# - How to rank operators
# - How to define the first migration target
# - How to interpret single-point benchmark results
# - How to keep the case wording neutral

# %% [markdown]
# ## Matching script
#
# `examples/10_end_to_end_generic.py`
