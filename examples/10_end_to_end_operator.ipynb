# %% [markdown]
# # Chapter 10 Operator Project Layer
#
# This notebook explains the operator-level project layer.
#
# Use this layer when you want to study a concrete subgraph slice and the corresponding benchmark/report workflow.

# %% [markdown]
# ## What this layer teaches
#
# - How to name the subgraph label
# - How to keep baseline and migrated paths aligned
# - How to interpret benchmark records
# - How to reason about trend scans
# - How to separate process wording from public-case wording

# %% [markdown]
# ## Matching script
#
# `examples/10_end_to_end_operator.py`
