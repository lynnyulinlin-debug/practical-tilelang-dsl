# %% [markdown]
# # Chapter 9 Overview Layer
#
# This notebook explains the shared comparison framework between TileLang and Triton.
#
# Use this layer to understand the design tradeoffs before choosing a route.

# %% [markdown]
# ## What this layer teaches
#
# - How the two DSLs target different constraints
# - How abstraction level affects control and portability
# - How to separate quick experimentation from migration-oriented development
# - How to frame an engineering choice as a decision, not a preference

# %% [markdown]
# ## Matching notebook
#
# `examples/09_triton_comparison.ipynb`
